# %%
import requests
import urllib.request
import time
from bs4 import BeautifulSoup
import re
import subprocess
import time

import numpy as np
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait

from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://www.welcometothejungle.com/fr/companies/sharies/jobs/business-developper_paris'
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text, 'html.parser',from_encoding="utf-8")

# %%
h1 = soup.find("div", {"class": "sc-11obzva-1 czRmi"})

# %%
h2=h1.findAll("div", {"class": "sc-11obzva-1 czRmi"})

# %%
h3=h2[2]

# %%
print(h3)
# Out:
# <div class="sc-11obzva-1 czRmi"><ul><li>Excellente maitrise du pack office (notamment Excel)
# </li><li>Rigueur et esprit d’analyse
# </li><li>Excellente aisance relationnelle
# </li><li>Esprit d’initiative et goût pour le travail en équipe
# </li><li>Une expérience dans le domaine de l’investissement immobilier serait un plus
# </li><li>Globalement, nous recherchons une tête bien faite :)
# </li></ul></div>

# %%
f = open('results.txt', 'a+')
for row in h3: 
    f.write(row.get_text())
f.close()

# %%
for row in h3: 
    print(row.get_text())
# Out:
# Excellente maitrise du pack office (notamment Excel)
# Rigueur et esprit d’analyse
# Excellente aisance relationnelle
# Esprit d’initiative et goût pour le travail en équipe
# Une expérience dans le domaine de l’investissement immobilier serait un plus
# Globalement, nous recherchons une tête bien faite :)

# %%
h3.get_text()
# Out:
# 'Excellente maitrise du pack office (notamment Excel)\nRigueur et esprit d’analyse\nExcellente aisance relationnelle\nEsprit d’initiative et goût pour le travail en équipe\nUne expérience dans le domaine de l’investissement immobilier serait un plus\nGlobalement, nous recherchons une tête bien faite :)\n'

# %%
f = open('results.txt', 'a+')
f.write(h3.get_text())
f.write('\n')
f.close()

# %%
url = "https://www.welcometothejungle.com/fr/jobs?page=1&configure%5Bfilters%5D=website.reference%3Awttj_fr&configure%5BhitsPerPage%5D=30&aroundQuery=France&refinementList%5Boffice.country_code%5D%5B%5D=FR&refinementList%5Bcontract_type_names.fr%5D%5B%5D=CDI&refinementList%5Bcontract_type_names.fr%5D%5B%5D=Stage&query=%22data%20analyst%22&range%5Bexperience_level_minimum%5D%5Bmin%5D=0&range%5Bexperience_level_minimum%5D%5Bmax%5D=1"
url_2 = 'https://www.welcometothejungle.com/fr/companies/kapten/jobs/data-analyst-h-f-cdi-paris_levallois-perret_KAPTE_8m2plWg'
base_search_URL = 'https://www.welcometothejungle.com/fr/jobs?query=%22Data%20Analyst%22'
class WTTScrapper():

    def __init__(self):
        '''Init bot'''
        self.driver = webdriver.Chrome(ChromeDriverManager().install())
        self.driver.wait = WebDriverWait(self.driver, 1)

    def MainPage(self):
        '''Go the the first page'''
        self.driver.get(url)
        
    def scroll(self):
        scroll_delta = int(i)*140
        self.driver.execute_script("window.scrollBy(0, "+str(scroll_delta) + ")")
        scroll_delta += 20

    def Click(self, pos):
        '''Click on the link'''
        self.driver.find_elements_by_class_name("ais-Hits-item")[pos].click()
        
    def GetHref(self):
        self.driver.find_elements_by_class_name("ais-Hits-item")[pos].click()
        
    def GetText(self):
        #data = self.driver.page_source
        data = requests.get(self.driver.current_url)
        #data = requests.get("https://www.welcometothejungle.com/fr/companies/jellysmack/jobs/data-analyst-h-f-corse_corte")
        soup = BeautifulSoup(data.text, 'html.parser',from_encoding="utf-8")
        h1 = soup.find("div", {"class": "sc-11obzva-1 czRmi"})
        h2 = h1.findAll("div", {"class": "sc-11obzva-1 czRmi"})
        h3 = h2[2]
        f = open('results.txt', 'a')
        f.write(h3.get_text())
        f.write('\n')
        f.close()

# %%
L = WTTScrapper()
for i in range(0,30):
    L.MainPage(scroll_delta)
    L.Click(i)
    L.GetText()
# Out:
# Looking for [chromedriver 80.0.3987.16 mac64] driver in cache
# File found in cache by path [/Users/alexandreminy/.wdm/drivers/chromedriver/80.0.3987.16/mac64/chromedriver]
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-57-ad167d9ff48d> in <module>
#       3 for i in range(0,30):
#       4     L.MainPage(scroll_delta)
# ----> 5     L.Click(i)
#       6     L.GetText()
#
# <ipython-input-56-6dc340d92d34> in Click(self, pos)
#      18     def Click(self, pos):
#      19         '''Click on the link'''
# ---> 20         self.driver.find_elements_by_class_name("ais-Hits-item")[pos].click()
#      21
#      22     def GetText(self):
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: disconnected: Unable to receive message from renderer
#   (Session info: chrome=80.0.3987.100)

# %%
def GetText(url):
    
    data_fp = requests.get(url)    
    soup_fp = BeautifulSoup(data_fp.text, 'html.parser',from_encoding="utf-8")
    class_url_offre = soup_fp.find("div", {"class":"sc-1kkiv1h-2 cHZvby"})
    url_offre = class_url_offre.findAll("a", href=True)

    data = requests.get(self.driver.current_url)
    soup = BeautifulSoup(data.text, 'html.parser',from_encoding="utf-8")
    h1 = soup.find("div", {"class": "sc-11obzva-1 czRmi"})
    h2 = h1.findAll("div", {"class": "sc-11obzva-1 czRmi"})
    h3 = h2[2]
    f = open('results.txt', 'a')
    f.write(h3.get_text())
    f.write('\n')
    f.close()

# %%
data_fp = requests.get("https://www.welcometothejungle.com/fr/jobs?page=2&configure%5Bfilters%5D=website.reference%3Awttj_fr&configure%5BhitsPerPage%5D=30&aroundQuery=France&refinementList%5Boffice.country_code%5D%5B%5D=FR&refinementList%5Bcontract_type_names.fr%5D%5B%5D=CDI&refinementList%5Bcontract_type_names.fr%5D%5B%5D=Stage&query=%22data%20analyst%22&range%5Bexperience_level_minimum%5D%5Bmin%5D=0&range%5Bexperience_level_minimum%5D%5Bmax%5D=1")    
soup_fp = BeautifulSoup(data_fp.text, 'html.parser',from_encoding="utf-8")
#url_offre = class_url_offre.findAll("a", href=True)
for offre in range(1,31,1):
    class_url_offre = soup_fp.find_all("div", {"class":"sc-1kkiv1h-2 cHZvby"})[i]
    for a in class_url_offre.find('a', href=True):
        print (a)
#print(url_offre)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-85-c49b3a7e593b> in <module>
#       3 #url_offre = class_url_offre.findAll("a", href=True)
#       4 for offre in range(1,31,1):
# ----> 5     class_url_offre = soup_fp.find_all("div", {"class":"sc-1kkiv1h-2 cHZvby"})[i]
#       6     for a in class_url_offre.find('a', href=True):
#       7         print (a)
#
# IndexError: list index out of range

# %%
data_fp = requests.get("https://www.welcometothejungle.com/fr/jobs?page=2&configure%5Bfilters%5D=website.reference%3Awttj_fr&configure%5BhitsPerPage%5D=30&aroundQuery=France&refinementList%5Boffice.country_code%5D%5B%5D=FR&refinementList%5Bcontract_type_names.fr%5D%5B%5D=CDI&refinementList%5Bcontract_type_names.fr%5D%5B%5D=Stage&query=%22data%20analyst%22&range%5Bexperience_level_minimum%5D%5Bmin%5D=0&range%5Bexperience_level_minimum%5D%5Bmax%5D=1")
soup_fp = BeautifulSoup(data_fp.text, 'html.parser')

class_url_offre = soup_fp.find_all({"class":"sc-1kkiv1h-2"}, href=True)
#url_offre = class_url_offre.find_all('a', href=True)
class_url_offre
#class_url_offre_2 = class_url_offre.find_all("a", {"class":"sc-1kkiv1h-2 cHZvby"})
# Out:
# []

# %%
soup_fp.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="fr">\n <head>\n  <script src="https://cdn.welcometothejungle.co/wttj-front/production/assets/env.js" type="text/javascript">\n  </script>\n  <title data-react-helmet="true">\n   Offres d\'emploi (CDI, CDD), apprentissages et stages | Welcome to the Jungle\n  </title>\n  <meta content="Liste des offres d\'emploi, stage, apprentissage et alternance dans les entreprises qui recrutent sur Welcome to the Jungle." data-react-helmet="true" name="description"/>\n  <meta content="jobs,offres d\'emploi,emploi,stage,alternance,apprentissage,offres de stage,entreprises,recrutement,startups,PME,grande entreprise,sociétés,recruteurs" data-react-helmet="true" name="keywords"/>\n  <meta content="Welcome to the Jungle - Travaillez dans la tribu qui vous correspond" data-react-helmet="true" property="og:title"/>\n  <meta content="Welcome to the Jungle - Travaillez dans la tribu qui vous correspond" data-react-helmet="true" name="twitter:title"/>\n  <meta content="Welcome to the Jungle est le guide qui vous accompagne dans votre recherche d\'emploi : découvrez en photos et vidéos la culture des meilleures entreprises où postuler. Toutes leurs offres d\'emploi CDI et CDD, stage, apprentissage et alternance." data-react-helmet="true" property="og:description"/>\n  <meta content="Welcome to the Jungle est le guide qui vous accompagne dans votre recherche d\'emploi : découvrez en photos et vidéos la culture des meilleures entreprises où postuler. Toutes leurs offres d\'emploi CDI et CDD, stage, apprentissage et alternance." data-react-helmet="true" name="twitter:description"/>\n  <meta content="https://cdn.welcometothejungle.co/wttj-front/production/assets/images/social/logo.png?v=b0a5946ab3c985a2410c173566375ec9" data-react-helmet="true" property="og:image"/>\n  <meta content="https://cdn.welcometothejungle.co/wttj-front/production/assets/images/social/logo.png?v=b0a5946ab3c985a2410c173566375ec9" data-react-helmet="true" name="twitter:image"/>\n  <meta content="https://www.welcometothejungle.com/fr/jobs" data-react-helmet="true" property="og:url"/>\n  <meta content="" data-react-helmet="true" property="og:type"/>\n  <meta content="fr" data-react-helmet="true" http-equiv="content-language"/>\n  <meta content="max-snippet:50, max-image-preview:large, max-video-preview:15" data-react-helmet="true" name="robots"/>\n  <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0" data-react-helmet="true" name="viewport"/>\n  <meta content="@WTTJ" data-react-helmet="true" name="twitter:site"/>\n  <meta content="summary_large_image" data-react-helmet="true" name="twitter:card"/>\n  <meta content="308225676054204" data-react-helmet="true" name="fb:app_id"/>\n  <meta content="#0b0b0d" data-react-helmet="true" name="theme-color"/>\n  <meta charset="utf-8" data-react-helmet="true"/>\n  <link data-react-helmet="true" href="https://www.welcometothejungle.com/fr/jobs" rel="canonical"/>\n  <link data-react-helmet="true" href="https://www.welcometothejungle.com/en/jobs" hreflang="en" rel="alternate"/>\n  <link data-react-helmet="true" href="https://www.welcometothejungle.com/fr/jobs" hreflang="fr" rel="alternate"/>\n  <link data-react-helmet="true" href="https://www.welcometothejungle.com/es/jobs" hreflang="es" rel="alternate"/>\n  <link data-react-helmet="true" href="https://www.welcometothejungle.com/cs/jobs" hreflang="cs" rel="alternate"/>\n  <link data-react-helmet="true" href="https://www.welcometothejungle.com/sk/jobs" hreflang="sk" rel="alternate"/>\n  <link data-react-helmet="true" href="/articles.rss" rel="alternate" type="application/rss+xml"/>\n  <link href="https://cdn.welcometothejungle.co/wttj-front/production/assets/images/favicon.ico?v=b9b18abf7da0a20c922fb6750eb935e3" rel="shortcut icon"/>\n  <link href="https://cdn.welcometothejungle.co/wttj-front/production/assets/vendors-13b2209de591deca64bc.css" rel="stylesheet" type="text/css"/>\n  <style data-styled="iMrUmY ghzkpM cHltbi gbfQPZ bvQzJc dyMdAC hVGFJO gcm ...
